# %% [markdown]
# # Final Preparation of Covariates

# %%
rm(list=ls())

# %%
library(ggplot2)

# %%
folder = getwd()
weather <- read.csv(file.path(folder, "data/weather/observed_data_2015_2023/final/weather_final.csv"))
capacity <-read.csv(file.path(folder, "data/installed_capacity/final/intalled_capacity.csv"))

# %%
head(weather)
# Out:
#   date       temperature_c_castelobranco pressure_msl_castelobranco
# 1 2015-01-01 1034.829                    5.375000
# 2 2015-01-02 1037.850                    5.887500
# 3 2015-01-03 1037.904                    7.095833
# 4 2015-01-04 1033.575                    7.141667
# 5 2015-01-05 1029.350                    6.912500
# 6 2015-01-06 1028.588                    3.483333
#   windspeed_100m_castelobranco temperature_c_evora pressure_msl_evora
# 1 9.033333                     1034.096            6.975000
# 2 9.845833                     1037.075            7.766667
# 3 9.170833                     1037.208            7.945833
# 4 7.362500                     1032.933            8.170833
# 5 7.854167                     1029.450            7.320833
# 6 6.308333                     1028.629            5.891667
#   windspeed_100m_evora temperature_c_faro pressure_msl_faro windspeed_100m_faro
# 1 16.312500            1033.300           11.67083          15.137500
# ...

# %%
head(capacity)
# Out:
#   date       smoothed_capacity
# 1 2015-01-01 4486
# 2 2015-01-02 4486
# 3 2015-01-03 4486
# 4 2015-01-04 4486
# 5 2015-01-05 4486
# 6 2015-01-06 4486

# %%
covariates <- merge(weather, capacity, by = "date")

# %%
for (covar in names(covariates)[-1]) {  
    tmp <- ts(covariates[[covar]], frequency = 365.25, start=c(2015, 01, 01))
    ts.plot(tmp, col=c("lightblue"), main = covar)
    }
# Out:
# Plot with title "temperature_c_castelobranco"
# Plot with title "pressure_msl_castelobranco"
# Plot with title "windspeed_100m_castelobranco"
# Plot with title "temperature_c_evora"
# Plot with title "pressure_msl_evora"
# Plot with title "windspeed_100m_evora"
# Plot with title "temperature_c_faro"
# Plot with title "pressure_msl_faro"
# Plot with title "windspeed_100m_faro"
# Plot with title "temperature_c_guarda"
# Plot with title "pressure_msl_guarda"
# Plot with title "windspeed_100m_guarda"
# Plot with title "temperature_c_leiria"
# Plot with title "pressure_msl_leiria"
# Plot with title "windspeed_100m_leiria"
# Plot with title "temperature_c_lisbona"
# Plot with title "pressure_msl_lisbona"
# Plot with title "windspeed_100m_lisbona"
# Plot with title "temperature_c_porto"
# Plot with title "pressure_msl_porto"
# Plot with title "windspeed_100m_porto"
# Plot with title "temperature_c_santarem"
# Plot with title "pressure_msl_santarem"
# ...

# %%
# Save the file
write.csv(covariates, file=file.path(folder, "data/covariates/covariates_2015_2023.csv"), row.names = FALSE)
